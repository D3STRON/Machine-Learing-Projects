# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import accuracy_score
from sklearn import svm

# %%
raw_mobile_data = pd.read_csv('./data/mobile_price_data.csv')

# %%
raw_mobile_data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# # Seperating Dependent and independent variables

# %%
y = raw_mobile_data.iloc[:,-1]
del raw_mobile_data["price_range"]

# %%
raw_mobile_data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %% [markdown]
# # Handeling null values

# %%
raw_mobile_data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
raw_mobile_data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %% [markdown]
# # Standardizing Values

# %%
# scaler = StandardScaler()
# X = scaler.fit_transform(raw_mobile_data)
# raw_mobile_data.describe()

X = np.array(raw_mobile_data)

# %% [markdown]
# # Splitting Training and Testing data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state= 4)

print(X_train.shape, X_test.shape)
# Out:
# (1800, 20) (200, 20)

# %%
sv = svm.SVC(kernel='rbf')
sv.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_train_pred = sv.predict(X_train)
y_test_pred = sv.predict(X_test)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)
print("Training accuracy for SVM:",train_acc, "\nTesting Accuracy on SVM", test_acc)
# Out:
# Training accuracy for SVM: 0.9561111111111111
# Testing Accuracy on SVM 0.96

# %%
lr = LogisticRegression()
# training the logistic regression model with the training data 
lr.fit(X_train, y_train)
# Out:
# C:\Users\GHOSH\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)
print("Training accuracy for Logistic:",train_acc, "\nTesting Accuracy on Logistic", test_acc)
# Out:
# Training accuracy for Logistic: 0.625
# Testing Accuracy on Logistic 0.665

# %%
rf = RandomForestRegressor(n_estimators = 100, random_state = 42)
rf.fit(X_train, y_train);

# %%
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

train_acc = rf.score(X_train, y_train)
test_acc = rf.score(X_test, y_test)
print("Training accuracy for Random Forest:",train_acc, "\nTesting Accuracy on Random Forest", test_acc)
# Out:
# Training accuracy for Random Forest: 0.991872761844753
# Testing Accuracy on Random Forest 0.9391287713782458

# %%
knn = KNeighborsRegressor(n_neighbors=40)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=40)

# %%
y_train_pred = knn.predict(X_train)
y_test_pred = knn.predict(X_test)

train_acc = knn.score(X_train, y_train)
test_acc = knn.score(X_test, y_test)
print("Training accuracy for KNN:",train_acc, "\nTesting Accuracy on KNN", test_acc)
# Out:
# Training accuracy for KNN: 0.9495600277181544
# Testing Accuracy on KNN 0.949215420746605
